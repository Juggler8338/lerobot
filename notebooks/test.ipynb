# %%
import gymnasium as gym
import lerobot
import numpy as np
import os

# 强制设置环境变量 (为了保险)
os.environ["MUJOCO_GL"] = "egl"

print("正在初始化环境...")
try:
    # 使用 LeRobot 里的一个简单环境，或者原生 MuJoCo 环境
    # 这里以 Aloha 环境为例 (如果已安装) 或者通用的 gym 环境
    env = gym.make("Ant-v4", render_mode="rgb_array") 
    
    obs, _ = env.reset()
    print("环境重置成功。")
    
    # 测试渲染
    img = env.render()
    print(f"渲染成功，图像形状: {img.shape}") 
    
    # 如果能走到这一步，说明 Headless 渲染没问题
    print("Headless 环境验证通过！")
    
except Exception as e:
    print(f"报错了: {e}")
    print("提示：检查是否安装了 libglew 或类似依赖，或者显卡驱动是否正常。")
# Out:
# 正在初始化环境...
# 环境重置成功。
# 渲染成功，图像形状: (480, 480, 3)
# Headless 环境验证通过！
# /usr1/home/s125mdg55_01/miniforge3/envs/lerobot/lib/python3.10/site-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment Ant-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(

# %% [markdown]
# python src/lerobot/scripts/lerobot_train.py \
#     --policy.type jit \
#     --env.type pusht \
#     --batch_size=64 \
#     --steps=200000 \
#     --dataset.repo_id lerobot/pusht \
#     --wandb.enable true \
#     --wandb.project test \
#     --policy.repo_id Russo0405/pusht
#
# lerobot-train
#     --policy.type jit \
#     --env.type pusht \
#     --dataset.repo_id lerobot/pusht \
#     --wandb.enable true \
#     --wandb.project test \
#     --policy.repo_id Russo0405/pusht

# %% [markdown]
# python src/lerobot/scripts/lerobot_train.py \
#     --policy.type act \
#     --env.type aloha \
#     --dataset.repo_id lerobot/aloha_mobile_cabinet \
#     --wandb.enable true \
#     --wandb.project lerobot_aloha \
#     --policy.repo_id Russo0405/aloha_mobile_cabinet

# %% [markdown]
# lerobot-eval \
#     --policy.path=outputs/train/2026-01-01/20-53-27_pusht_jit/checkpoints/020000/pretrained_model \
#     --env.type=pusht \
#     --eval.n_episodes=128 \
#     --eval.batch_size=64 \
#     --policy.device=cuda

# %% [markdown]
# accelerate launch --multi_gpu --num_processes=2 --mixed_precision=fp16 \
#   $(which lerobot-eval) \
#     --policy.path=outputs/train/2025-12-30/18-37-28_act_dual_gpu/checkpoints/020000/pretrained_model \
#     --env.type=aloha \
#     --eval.n_episodes=50 \
#     --eval.batch_size=16 \
#     --policy.device=cuda

# %% [markdown]
# MUJOCO_GL=egl accelerate launch --multi_gpu --num_processes=2 --mixed_precision=fp16 \
#   $(which lerobot-train) \
#   --dataset.repo_id=lerobot/aloha_sim_transfer_cube_human \
#   --env.type aloha \
#   --env.task=AlohaTransferCube-v0 \
#   --policy.type=act \
#   --batch_size=8 \
#   --steps=200000 \
#   --job_name=act \
#   --wandb.enable true \
#   --wandb.project dual \
#   --policy.repo_id Russo0405/aloha_sim_transfer_cube_human

# %% [markdown]
# MUJOCO_GL=egl accelerate launch --multi_gpu --num_processes=2 --mixed_precision=fp16 \
#   $(which lerobot-train) \
#   --dataset.repo_id=lerobot/aloha_sim_insertion_human \
#   --env.type aloha \
#   --env.task=AlohaInsertion-v0 \
#   --policy.type=act \
#   --batch_size=8 \
#   --steps=200000 \
#   --job_name=act_insertion \
#   --wandb.enable true \
#   --wandb.project insert \
#   --policy.repo_id Russo0405/aloha_sim_insertion_human

# %% [markdown]
# accelerate launch --multi_gpu --num_processes=2 --mixed_precision=fp16 \
#   $(which lerobot-train) \
#   --dataset.repo_id=lerobot/pusht \
#   --env.type pusht \
#   --policy.type=jit \
#   --batch_size=64 \
#   --steps=100000 \
#   --job_name=jit \
#   --wandb.enable true \
#   --wandb.project test \
#   --policy.repo_id Russo0405/pusht

# %% [markdown]
# python -c "from lerobot_policy_dit import DiTConfig"

# %% [markdown]
# tmux new -s lerobot

# %% [markdown]
# tmux ls
# tmux new -s test
# tmux attach -t test
# exit

# %% [markdown]
# tmux kill-session -t lerobot_diffusion
